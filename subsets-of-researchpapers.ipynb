# %% [markdown]
# # Subsets of Research Papers

# %%
# %load_ext autoreload
# %autoreload 2
import pandas as pd
from cord.cord19 import ResearchPapers
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\dwight\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
research_papers = ResearchPapers.from_data_dir()
#research_papers = ResearchPapers.from_pickle()
# Out:
# Loading metadata from data\CORD-19-research-challenge
# Cleaning metadata
# Fixing dates that are a list e.g. ['2020-02-05', '2020-02']
# Fixing dates with the seasons e.g. 2014 Autumn
# Fix dates like 2016 Nov 9 Jan-Feb
# Fix dates like 2012 Jan-Mar
# Convert Dates like 2020 Apr 13
# Converting Dates like 2020 Apr
# Converting Dates like 2020
# Converting Dates like 2020-01-21
# Indexing research papers
# Finished Indexing in 39.0 seconds

# %%
research_papers.save()
# Out:
# Saving to data\ResearchPapers.pickle

# %%
research_papers
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>title</th>
#       <th>abstract</th>
#       <th>journal</th>
#       <th>source</th>
#       <th>authors</th>
#       <th>has_text</th>
#       <th>published</th>
#       <th>when</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Intrauterine virus infections and congenital h...</td>
#       <td>The etiologic basis for the vast majority of ...</td>
#       <td>American Heart Journal</td>
#       <td>Elsevier</td>
#       <td>Overall, James C.</td>
#       <td>False</td>
#       <td>1972-12-31</td>
#       <td>47 years ago</td>
#     </tr>
#     <tr>
#       <th>1</th>
# ...

# %% [markdown]
# ### Head

# %%
first10 = research_papers.head(10)
# Out:
# Creating a new ResearchPapers instance from an old one

# %%
first10.searchbar('Clinical Supplies')
# Out:
# interactive(children=(Text(value='Clinical Supplies', description='SearchTerms'), Output()), _dom_classes=('wi…

# %%
tail10 = research_papers.tail(10)
# Out:
# Creating a new ResearchPapers instance from an old one

# %%
tail10
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>title</th>
#       <th>abstract</th>
#       <th>journal</th>
#       <th>source</th>
#       <th>authors</th>
#       <th>has_text</th>
#       <th>published</th>
#       <th>when</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>44210</th>
#       <td>The intrinsic vulnerability of networks to epi...</td>
#       <td>Contact networks are convenient models to inve...</td>
#       <td>Ecol Modell</td>
#       <td>PMC</td>
#       <td>Strona, G.; Carstens, C.J.; Beck, P.S.A.; Han,...</td>
#       <td>True</td>
#       <td>2018-09-10</td>
#       <td>1 year ago</td>
#     </tr>
#     <tr>
# ...

# %%
research_papers.metadata.tail(4)
# Out:
#                                             sha    source  \
# 44216  ec575d33c0d3b34af7644fcfed64af045a75ab63  Elsevier
# 44217  7f8715a818bfd325bf4413d3c07003d7ce7b6f7e       PMC
# 44218  07e78e218a159c35e9599e3751a99551a271597b  Elsevier
# 44219  04bc03c90437934a75fc6fdc228817234ef84c3a       PMC
#
#                                                    title  \
# 44216  Functional Analysis of the Transmembrane Domai...
# 44217  Viral Entry Properties Required for Fitness in...
# 44218  Arenavirus reverse genetics: New approaches fo...
# 44219  A New Immunosuppressive Molecule Emodin Induce...
#
#                                doi       pmcid pubmed_id    license  \
# 44216    10.1016/j.jmb.2008.12.029  PMC2750892  19121325  els-covid
# 44217        10.1128/mBio.00898-18  PMC6030562  29970463      cc-by
# 44218  10.1016/j.virol.2011.01.013  PMC3057228  21324503  els-covid
# 44219     10.3389/fimmu.2017.01519  PMC5682309  29167674      cc-by
#
# ...

# %% [markdown]
# ### Query

# %%
research_papers.query("has_text")
# Out:
# Creating a new ResearchPapers instance from an old one
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>title</th>
#       <th>abstract</th>
#       <th>journal</th>
#       <th>source</th>
#       <th>authors</th>
#       <th>has_text</th>
#       <th>published</th>
#       <th>when</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>3</th>
#       <td>Clinical and immunologic studies in identical ...</td>
#       <td>Middle-aged female identical twins, one of wh...</td>
#       <td>The American Journal of Medicine</td>
#       <td>Elsevier</td>
#       <td>Brunner, Carolyn M.; Horwitz, David A.; Shann,...</td>
#       <td>True</td>
# ...

# %%
research_papers.query('published > "2019-11-01"')
# Out:
# Creating a new ResearchPapers instance from an old one
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>title</th>
#       <th>abstract</th>
#       <th>journal</th>
#       <th>source</th>
#       <th>authors</th>
#       <th>has_text</th>
#       <th>published</th>
#       <th>when</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1921</th>
#       <td>Infectious Diseases and Agriculture</td>
#       <td>Synopsis • Agriculture has huge impacts on hum...</td>
#       <td>Encyclopedia of Food Security and Sustainability</td>
#       <td>Elsevier</td>
#       <td>Grace, Delia</td>
#       <td>True</td>
#       <td>2019-12-31</td>
# ...
