# %% [markdown]
# # Metadata Analysis

# %%
import pandas as pd
from cord import ResearchPapers

# %%
research_papers = ResearchPapers.load()
# Out:
# Loading metadata from data\CORD-19-research-challenge
# Cleaning metadata
#
# Indexing research papers
# Creating the BM25 index from the abstracts of the papers
# Use index="text" if you want to index the texts of the paper instead
# Finished Indexing in 36.0 seconds

# %%
metadata = research_papers.metadata

# %%
metadata[metadata.sha.fillna('').str.contains(';')]
# Out:
#        cord_uid                                                sha    source  \
# 2399   fpj5urao  e9c78584c08ba79d735e150eff98297eb57f12dd; 4a22...       PMC
# 2482   2vlvz5o9  bd92cbae7179f07d59d1ce4d7ca96e37ebb40ec9; 7526...       PMC
# 2589   2g4m0dy7  2bd6e33d92632dfcba4056a2d7355ced5b7ab1fd; 6fe7...       PMC
# 2648   cxzlmfst  4eb6e165ee705e2ae2a24ed2d4e67da42831ff4a; d4f0...       PMC
# 2650   br2p09pg  daee7f7d31f4bf1c0ef883bcd6c124b6e94cbee7; ad9a...       PMC
# ...         ...                                                ...       ...
# 45749  rcpb2fyy  d14208a77004363b34b3cf0b7d08fd0d121e12a4; 7f7c...       PMC
# 45751  6lr81vir  1b5064ad9a2828b30813ac5634d98b5da2f1d3d9; 0391...  Elsevier
# 45766  8f6gpdy2  f9d941d30a663db32ceabe367cf36b6f3c2c744c; 1f19...  Elsevier
# 45767  b7e9grj0  889ba9338ea71cd42c3bc675db30a1928d487f43; d38e...  Elsevier
# 45773  28vx9w58  3369a14e1d116943f48b3a33597796c9802de279; f523...       PMC
#
# ...
